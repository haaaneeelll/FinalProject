# %%
import pandas as pd

# %%
df = pd.read_csv('다문화_통합데이터.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Columns: 135 entries, 행정구 to 2022_특별학급수
# dtypes: float64(27), int64(107), object(1)
# memory usage: 26.5+ KB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# 경고 무시하기
warnings.filterwarnings("ignore")
# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
plt.figure(figsize=(22, 8))

sns.barplot(x=df['행정구'], y=df['2022_초등학교_계'], palette="Set2")
# Out:
# <Axes: xlabel='행정구', ylabel='2022_초등학교_계'>

# %%
plt.figure(figsize=(22, 8))

sns.barplot(x=df['행정구'], y=df['2022_다문화가구_소계'], palette="Set2")
# Out:
# <Axes: xlabel='행정구', ylabel='2022_다문화가구_소계'>

# %%
plt.figure(figsize=(18, 8))

sns.barplot(x=df['행정구'], y=df['2022_가구원_소계'], palette="Set2")
# Out:
# <Axes: xlabel='행정구', ylabel='2022_가구원_소계'>

# %%
s1 = df[['2022_초등학생_국내출생자녀_소계','2022_초등학생_외국인가정자녀_소계','2022_초등학생_중도입국자녀_소계']].sum()
s1
# Out:
# 2022_초등학생_국내출생자녀_소계     7925
# 2022_초등학생_외국인가정자녀_소계    4046
# 2022_초등학생_중도입국자녀_소계      808
# dtype: int64

# %%
plt.figure(figsize=(10, 8))

sns.barplot(x=s1.index, y=s1, palette="Set2")
# Out:
# <Axes: >

# %%
df_1 = df.loc[..., '2022_초등학생_국내출생자녀_소계':'2022_초등학생_국내출생자녀_기타']

# %%
df_1.columns
# Out:
# Index(['2022_초등학생_국내출생자녀_소계', '2022_초등학생_국내출생자녀_일본', '2022_초등학생_국내출생자녀_중국',
#        '2022_초등학생_국내출생자녀_중국_한국계', '2022_초등학생_국내출생자녀_대만', '2022_초등학생_국내출생자녀_몽골',
#        '2022_초등학생_국내출생자녀_필리핀', '2022_초등학생_국내출생자녀_베트남', '2022_초등학생_국내출생자녀_태국',
#        '2022_초등학생_국내출생자녀_캄보디아', '2022_초등학생_국내출생자녀_인도네시아',
#        '2022_초등학생_국내출생자녀_중앙아시아', '2022_초등학생_국내출생자녀_미국', '2022_초등학생_국내출생자녀_러시아',
#        '2022_초등학생_국내출생자녀_러시아 및 중앙아시아_한국계', '2022_초등학생_국내출생자녀_중동',
#        '2022_초등학생_국내출생자녀_유럽', '2022_초등학생_국내출생자녀_아프리카', '2022_초등학생_국내출생자녀_기타'],
#       dtype='object')

# %%
df_2 = df.loc[..., '2022_초등학생_외국인가정자녀_소계':'2022_초등학생_외국인가정자녀_기타']

# %%
df_2.columns = df_1.columns

# %%
df_3 = df.loc[..., '2022_초등학생_중도입국자녀_소계':'2022_초등학생_중도입국자녀_기타']

# %%
df_3.columns = df_1.columns

# %%
s2 = pd.concat([df_1, df_2, df_3]).sum()
s2
# Out:
# 2022_초등학생_국내출생자녀_소계                 12779
# 2022_초등학생_국내출생자녀_일본                   686
# 2022_초등학생_국내출생자녀_중국                  4582
# 2022_초등학생_국내출생자녀_중국_한국계              1638
# 2022_초등학생_국내출생자녀_대만                   145
# 2022_초등학생_국내출생자녀_몽골                   494
# 2022_초등학생_국내출생자녀_필리핀                  775
# 2022_초등학생_국내출생자녀_베트남                 2533
# 2022_초등학생_국내출생자녀_태국                   119
# 2022_초등학생_국내출생자녀_캄보디아                 283
# 2022_초등학생_국내출생자녀_인도네시아                 43
# 2022_초등학생_국내출생자녀_중앙아시아                249
# 2022_초등학생_국내출생자녀_미국                   260
# 2022_초등학생_국내출생자녀_러시아                  124
# 2022_초등학생_국내출생자녀_러시아 및 중앙아시아_한국계       87
# 2022_초등학생_국내출생자녀_중동                    66
# 2022_초등학생_국내출생자녀_유럽                   149
# 2022_초등학생_국내출생자녀_아프리카                 110
# 2022_초등학생_국내출생자녀_기타                   436
# dtype: int64

# %%
s2.index = ['_'.join(i.split('_')[3:]) for i in s2.index]

# %%
s2
# Out:
# 소계                 12779
# 일본                   686
# 중국                  4582
# 중국_한국계              1638
# 대만                   145
# 몽골                   494
# 필리핀                  775
# 베트남                 2533
# 태국                   119
# 캄보디아                 283
# 인도네시아                 43
# 중앙아시아                249
# 미국                   260
# 러시아                  124
# 러시아 및 중앙아시아_한국계       87
# 중동                    66
# 유럽                   149
# 아프리카                 110
# 기타                   436
# dtype: int64

# %%
plt.figure(figsize=(15, 8))

sns.barplot(x=s2.index[1:], y=s2[1:], palette="Set2")
# Out:
# <Axes: >

# %%
df['사회적 신뢰_국내 거주 외국인'] = df['사회적 신뢰_국내 거주 외국인']*10
df['사회적 신뢰_국내 거주 외국인']
# Out:
# 0     30.7
# 1     28.6
# 2     37.6
# 3     30.8
# 4     23.2
# 5     27.6
# 6     31.3
# 7     21.7
# 8     20.4
# 9     35.3
# 10    13.3
# 11    27.7
# 12    28.3
# 13    27.0
# 14    41.6
# 15    21.7
# 16    33.3
# 17    27.9
# 18     9.1
# 19    32.7
# 20    22.0
# 21    31.4
# 22    16.5
# 23    30.9
# 24    19.9
# Name: 사회적 신뢰_국내 거주 외국인, dtype: float64

# %%
dfdf = pd.read_csv('다문화통합데이터정리.csv')

# %%
dfdf.to_csv('다문화통합데이터정리_cp949.csv', index=False, encoding='cp949')
